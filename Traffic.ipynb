# %%
import os
import torch
from IPython.display import Image, clear_output
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 2.2.1+cu121 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %%
# !git clone https://github.com/ultralytics/yolov3
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 11255, done.
# remote: Counting objects: 100% (1177/1177), done.
# remote: Compressing objects: 100% (531/531), done.
# remote: Total 11255 (delta 827), reused 948 (delta 645), pack-reused 10078
# Receiving objects: 100% (11255/11255), 9.99 MiB | 24.25 MiB/s, done.
# Resolving deltas: 100% (7626/7626), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Machine_Learning/train/images
# Out:
# /content/drive/MyDrive/Machine_Learning/train/images

# %%
file = open("train_images_roboflow.txt", "w")
for root, dirs, files in os.walk("."):
    for filename in files:
      # print("../train/images/" + filename)
      if filename == "train_images_roboflow.txt":
        pass
      else:
        file.write("../train/images/" + filename + "\n")
file.close()

# %%
# %cd /content/drive/MyDrive/Machine_Learning/valid/images
# Out:
# /content/drive/MyDrive/Machine_Learning/valid/images

# %%
file = open("valid_images_roboflow.txt", "w")
for root, dirs, files in os.walk("."):
    for filename in files:
      # print("../train/images/" + filename)
      if filename == "valid_images_roboflow.txt":
        pass
      else:
        file.write("../valid/images/" + filename + "\n")
file.close()

# %%
# %cd /content/yolov3
# Out:
# /content/yolov3

# %%
pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.1.42-py3-none-any.whl (749 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.1 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 448 --batch 32 --epochs 20 --data /content/yolov3/data/data.yaml
# Out:
# 2024-04-03 15:34:10.413504: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-03 15:34:10.413554: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-03 15:34:10.414998: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from utils.plots import *; plot_results('/content/yolov3/runs/train/exp3/results.csv')

# %%
# !python3 detect.py --weights /content/yolov3/runs/train/exp3/weights/last.pt --source=/content/drive/MyDrive/Machine_Learning/test/images --name=/content/drive/MyDrive/Machine_Learning/data.yaml
# Out:
# detect: weights=['/content/yolov3/runs/train/exp3/weights/last.pt'], source=/content/drive/MyDrive/Machine_Learning/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=/content/drive/MyDrive/Machine_Learning/data.yaml, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv3 🚀 v9.6.0-168-gcff02836 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 38 layers, 8675932 parameters, 0 gradients, 12.9 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/279 /content/drive/MyDrive/Machine_Learning/test/images/aguanambi-1000_png_jpg.rf.7179a0df58ad6448028bc5bc21dca41e.jpg: 640x640 2 bicycles, 7 cars, 2 motorbikes, 1 person, 7.8ms
# ...
